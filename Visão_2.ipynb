# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaCristina1972/ProjetoOpenVC/blob/main/Vis%C3%A3o_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Visão Computacional

# %%
import skimage.feature
import skimage.segmentation
import matplotlib.pyplot as plt
import cv2 
import numpy as np

# %%
img=cv2.imread('A1.jpg',0)

# %%
#img1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
img_ku = skimage.feature.local_binary_pattern(img, 8, 1.0, method='default') 
img_ku = img_ku.astype(np.uint8)
hist=cv2.calcHist([img_ku],[0],None,[256],[0,256])
hist=cv2.normalize(hist,hist)

# %%
plt.plot(hist, color='r')
plt.xlim(2,256)
plt.show()
plt.imshow(img_ku,cmap='Greys_r')
plt.show()
